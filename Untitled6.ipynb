# %% [markdown]
# <a href="https://colab.research.google.com/github/deekshitha411/bits_5d5/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, SimpleRNN, Dense
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('/content/optimized_waste_management_data.csv')
df.head(2)
# Out:
#          date  waste_volume  organic_waste  recyclable_waste  hazardous_waste  \
# 0  01-01-2020         48.85          31.49             12.55             4.81
# 1  02-01-2020         49.45          29.76             14.76             4.94
#
#   collection_frequency  landfill_capacity_used  recycling_rate
# 0               Weekly                   55.87           47.37
# 1               Weekly                   51.91           41.70

# %%
df.tail(2)
# Out:
#             date  waste_volume  organic_waste  recyclable_waste  \
# 1459  30-12-2023         53.66          31.85             16.64
# 1460  31-12-2023         53.62          29.58             19.70
#
#       hazardous_waste collection_frequency  landfill_capacity_used  \
# 1459             5.18            Bi-weekly                   47.90
# 1460             4.33            Bi-weekly                   44.74
#
#       recycling_rate
# 1459           46.69
# 1460           48.19

# %%
data = df.waste_volume.values
#data.shape
print(data[11])
# Out:
# 53.05

# %%
sequence_length = 10
for i in range(len(data)-sequence_length):
    print(data[i:i+sequence_length])
    print(data[i+sequence_length])
    if i==2:
      break
# Out:
# [48.85 49.45 51.03 54.7  51.74 54.58 59.18 53.31 53.1  56.65]
# 49.92
# [49.45 51.03 54.7  51.74 54.58 59.18 53.31 53.1  56.65 49.92]
# 53.05
# [51.03 54.7  51.74 54.58 59.18 53.31 53.1  56.65 49.92 53.05]
# 55.72

# %%
data = df.waste_volume.values
input_data = []
Labels = []
for i in range(0,10):
  print('Pattern:' ,i+1, '=',data[i:i+10])
  print('Label for pattern', i+1, '=',data[i+10])
